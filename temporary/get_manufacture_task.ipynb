# %%
import numpy as np
import pandas as pd  
import time

# %%
dfUser = pd.read_csv('../data_csv/User.csv')
dfOrderDetail = pd.read_csv('../data_csv/OrderDetail.csv')
dfOrderDetail = dfOrderDetail.rename(columns= {"code" : 'code_order' , 'name' : 'name_order'})
dfManufactureTaskStatus = pd.read_csv('../data_csv/ManufactureTaskStatus.csv')
dfManufactureTaskStatus
# Out:
#    id       code           name description  created_at  updated_at  \
# 0   1     review   Chờ sản xuất         NaN         NaN         NaN
# 1   2   approval  Đang sản xuất         NaN         NaN         NaN
# 2   3  completed       Hoàn tất         NaN         NaN         NaN
# 3   4   imported     Đã nhập đủ  Đã nhập đủ         NaN         NaN
#
#    deleted_at
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN

# %%
dfManufactureTask = pd.read_csv('../data_csv/ManufactureTask.csv')
dfManufactureTaskStatus = pd.read_csv('../data_csv/ManufactureTaskStatus.csv')
dfManufactureTaskDetail = pd.read_csv('../data_csv/ManufactureTaskDetail.csv')
dfManufactureTaskLink = pd.read_csv('../data_csv/ManufactureTaskLink.csv')
dfManufactureDeptDetail = pd.read_csv('../data_csv/ManufactureDeptDetail.csv')
dfManufactureDeptDetail = dfManufactureDeptDetail.rename(columns= {'code' : 'code_dept' , 'name' : 'name_dept'})
dfManufactureTaskDetail[dfManufactureTaskDetail['task_id'] == 1354]
dfManufactureTaskDetail
# dfManufactureTaskDetail.loc[1794]
# Out:
#                          code                                       name  \
# 0     6374746698b351668576358  CIE-211222-PBCap - Century Bar - Whitaker
# 1     63c4a5442cb331673831748                           HM-221206-WYSSEN
# 2     63dc606aca34d1675386986    TTD-221112-MIZUNO RB FAITHFUL CAP WHITE
# 3     63dc61b1011251675387313    TTD-221112-MIZUNO RB FAITHFUL CAP BLACK
# 4     63dc629cd13921675387548    TTD-221112-MIZUNO RB FAITHFUL CAP BLACK
# ...                       ...                                        ...
# 1824  63e468bbe6cb71675913403             TTD-221112-SP-V-S23SUC-BH11-LK
# 1825  63e4692578e071675913509             TTD-221112-SP-V-S23SUC-BH11-YG
# 1826  63e6f822134531676081186      CIE-221218-Distance Nirvana BK Hat SM
# 1827  63e6fb7284a111676082034     CIE-221218-Distance Nirvana BK Hat LXL
# 1828  63edd0d379d001676529875             DYC-US-230210-E11even-705-1005
#
#                                        qrcode  \
# 0     1668576421-DPSX-6374746698b351668576358
# 1     1673831819-DPSX-63c4a5442cb331673831748
# 2     1675387089-DPSX-63dc606aca34d1675386986
# 3     1675387416-DPSX-63dc61b1011251675387313
# 4     1675387589-DPSX-63dc629cd13921675387548
# ...                                       ...
# 1824  1675913439-DPSX-63e468bbe6cb71675913403
# 1825  1675913607-DPSX-63e4692578e071675913509
# 1826  1676081190-DPSX-63e6f822134531676081186
# 1827  1676082068-DPSX-63e6fb7284a111676082034
# 1828  1676529909-DPSX-63edd0d379d001676529875
#
#                                             description  creator_id  \
# 0     <figure class="image"><img src="https://s3-s3....         369
# 1     <figure class="image"><img src="https://s3-s3....         369
# 2     <figure class="image"><img src="https://s3-s3....         369
# 3     <figure class="image"><img src="https://s3-s3....         369
# 4     <p><img src="https://s3-s3.app.tms-s.vn/ttd/ta...         369
# ...                                                 ...         ...
# 1824  <p><img src="https://s3-s3.app.tms-s.vn/ttd/ta...         369
# 1825  <p><img src="https://s3-s3.app.tms-s.vn/ttd/ta...         369
# 1826  <p><img src="https://s3-s3.app.tms-s.vn/ttd/ta...         369
# 1827  <p><img src="https://s3-s3.app.tms-s.vn/ttd/ta...         369
# 1828  <p><img src="https://s3-s3.app.tms-s.vn/ttd/ta...         369
#
#                      created_at                 updated_at  deleted_at  \
# 0     2022-11-16 12:27:01+00:00  2022-11-16 12:27:01+00:00         NaN
# 1     2023-01-16 08:16:59+00:00  2023-01-16 08:17:00+00:00         NaN
# 2     2023-02-03 08:18:09+00:00  2023-02-03 08:18:12+00:00         NaN
# 3     2023-02-03 08:23:36+00:00  2023-02-03 08:23:38+00:00         NaN
# 4     2023-02-03 08:26:29+00:00  2023-02-03 08:26:30+00:00         NaN
# ...                         ...                        ...         ...
# 1824  2023-02-09 10:30:39+00:00  2023-02-22 09:58:20+00:00         NaN
# 1825  2023-02-09 10:33:27+00:00  2023-02-25 13:15:21+00:00         NaN
# 1826  2023-02-11 09:06:30+00:00  2023-02-23 10:11:12+00:00         NaN
# 1827  2023-02-11 09:21:08+00:00  2023-02-23 10:08:30+00:00         NaN
# 1828  2023-02-16 13:45:09+00:00  2023-03-01 08:25:45+00:00         NaN
#
#       manufacture_dept_id  start_time  ... status_id  order_id  task_id  \
# 0                       4  2022-11-16  ...         1      1358      490
# 1                       1  2023-02-14  ...         1      2820     1136
# 2                       2  2023-02-13  ...         1      2865     1178
# 3                       2  2023-02-13  ...         1      2866     1182
# 4                       3  2023-02-22  ...         1      2866     1183
# ...                   ...         ...  ...       ...       ...      ...
# 1824                    3  2023-03-10  ...         4      2882     1430
# 1825                    3  2023-03-10  ...         4      2883     1432
# 1826                    3  2023-03-06  ...         4      2689     1451
# 1827                    3  2023-03-06  ...         4      2690     1458
# 1828                    3  2023-03-09  ...         4      2978     1604
#
#       user_del_id  user_comp_id  description_del  min_prod_quan  \
# 0             NaN           NaN              NaN            NaN
# 1             NaN           NaN              NaN         1500.0
# 2             NaN           NaN              NaN         3091.0
# 3             NaN           NaN              NaN         3091.0
# 4             NaN           NaN              NaN         5002.0
# ...           ...           ...              ...            ...
# 1824          NaN           NaN              NaN         4000.0
# 1825          NaN           NaN              NaN         4000.0
# 1826          NaN           NaN              NaN          289.0
# 1827          NaN           NaN              NaN          238.0
# 1828          NaN           NaN              NaN          201.0
#
#       total_prod_quan  code_status   name_status
# 0                 NaN       review  Chờ sản xuất
# 1              3000.0       review  Chờ sản xuất
# 2             28143.0       review  Chờ sản xuất
# 3             28143.0       review  Chờ sản xuất
# 4              5002.0       review  Chờ sản xuất
# ...               ...          ...           ...
# 1824           4000.0     imported    Đã nhập đủ
# 1825           4000.0     imported    Đã nhập đủ
# 1826            289.0     imported    Đã nhập đủ
# 1827            238.0     imported    Đã nhập đủ
# 1828            201.0     imported    Đã nhập đủ
#
# [1829 rows x 21 columns]

# %%
dfUserDel =  dfUser.rename(columns= {"creator_id" : 'user_del_id' , 'fullname' : 'fullname_del'})
dfUserComp =  dfUser.rename(columns= {"creator_id" : 'user_comp_id' , 'fullname' : 'fullname_comp'})

dfManufactureTaskDetail = dfManufactureTaskDetail.merge(dfUser, on = 'creator_id' , how = 'left')
dfManufactureTaskDetail = dfManufactureTaskDetail.merge(dfOrderDetail[['code_order' , 'name_order' , 'order_id']], on = 'order_id' , how = 'left')
dfManufactureTaskDetail = dfManufactureTaskDetail.merge(dfManufactureDeptDetail[['code_dept' , 'name_dept' , 'manufacture_dept_id']], on = 'manufacture_dept_id' , how = 'left')
dfManufactureTaskDetail = dfManufactureTaskDetail.merge(dfUserDel, on = 'user_del_id' , how = 'left')
dfManufactureTaskDetail = dfManufactureTaskDetail.merge(dfUserComp, on = 'user_comp_id' , how = 'left')

# %%
dfManufactureTaskDetail.tail(1)
dfManufactureTaskDetail.loc[790]
# Out:
# code                                             63743cde777ba1668562142
# name                                                       HM-221114-A&A
# qrcode                           1668562187-DPSX-63743cde777ba1668562142
# description            <figure class="image"><img src="https://s3-s3....
# creator_id                                                           369
# created_at                                     2022-11-16 08:29:47+00:00
# updated_at                                     2022-12-12 09:21:57+00:00
# deleted_at                                                           NaN
# manufacture_dept_id                                                    4
# start_time                                                    2022-12-05
# end_time                                                      2022-12-08
# status_id                                                              3
# order_id                                                            2278
# task_id                                                              458
# user_del_id                                                          NaN
# user_comp_id                                                         NaN
# description_del                                                      NaN
# min_prod_quan                                                        NaN
# total_prod_quan                                                      NaN
# code_status                                                    completed
# name_status                                                     Hoàn tất
# fullname                                                   Phan Văn Tình
# code_order                                                 HM-221114-A&A
# name_order                                                 HM-221114-A&A
# code_dept                                                       chuan_bi
# name_dept                                                       Chuẩn bị
# fullname_del                                                         NaN
# fullname_comp                                                        NaN
# Name: 790, dtype: object

# %%
from bs4 import BeautifulSoup
a = 0

for i in range(0 , dfManufactureTaskDetail.shape[0]):
    aReq = dfManufactureTaskDetail.loc[i]
    soup = BeautifulSoup(aReq['description']).get_text()
    dfManufactureTaskDetail.at[aReq.name , 'description'] = soup

# %%
dfManufactureTaskDetail.head(2)
dfManufactureTaskDetail[dfManufactureTaskDetail['task_id'] == 1532]
# Out:
#                          code                                    name  \
# 1741  63ec36c9729a11676424905  DYC-US-221223-Nikki St Barth-684-Opt01
#
#                                        qrcode description  creator_id  \
# 1741  1676424915-DPSX-63ec36c9729a11676424905                     369
#
#                      created_at                 updated_at  deleted_at  \
# 1741  2023-02-15 08:35:15+00:00  2023-02-16 08:26:02+00:00         NaN
#
#       manufacture_dept_id  start_time  ... total_prod_quan  code_status  \
# 1741                    2  2023-02-17  ...           723.0    completed
#
#       name_status       fullname                              code_order  \
# 1741     Hoàn tất  Phan Văn Tình  DYC-US-221223-Nikki St Barth-684-Opt01
#
#                                   name_order  code_dept  name_dept  \
# 1741  DYC-US-221223-Nikki St Barth-684-Opt01        cat        Cắt
#
#       fullname_del fullname_comp
# 1741           NaN           NaN
#
# [1 rows x 28 columns]

# %%
dfManufactureTaskDetailFix = dfManufactureTaskDetail.drop(columns= {'code', 'qrcode' , 'creator_id' , 'deleted_at' , 'manufacture_dept_id', 'status_id' , 'order_id' , 'user_del_id' ,
                                                                    'user_comp_id' , 'description_del' })

new_col1 = ['task_id','name' , 'description' , 'code_order' ,'name_order', 'code_dept' ,  'name_dept','fullname', 'created_at', 'updated_at' , 'start_time' , 
      'end_time', 'min_prod_quan', 'total_prod_quan', 'code_status' , 'name_status' , 'fullname_del' , 'fullname_comp']
   
dfManufactureTaskDetailFix= dfManufactureTaskDetailFix.reindex(columns=new_col1)
   
dfManufactureTaskDetailFix.rename(columns = { 'name': 'Tên công việc', 'description': 'Mô tả CV', 'created_at' : 'Ngày tạo' , 'updated_at': 'Ngày Hoàn thành' ,'start_time' : 'Ngày BĐ dự kiến' , 'end_time' : 'Ngày kết thúc dự kiến',
                                             'fullname_del' : 'Nguời xóa CV' , 'fullname_comp' : 'Nguời hoàn tất CV' , 'description_del' : 'Lý do xóa CV' , 
                                             'min_prod_quan': 'Đồng bộ CV', 'total_prod_quan': 'Tổng số BTP', 'code_status': 'Mã trạng thái', 'name_status' : 'Trạng thái CV' ,
                                        'fullname': 'Người tạo CV' , 'code_order': 'Mã đơn hàng' , 'name_order': 'Tên ĐH' , 'code_dept': 'Mã bộ phận',
                                        'name_dept':'Tên bộ phận'}, inplace = True)
dfManufactureTaskDetailFix.tail(10)
# Out:
#       task_id                            Tên công việc Mô tả CV  \
# 1819     1354  TTD-221216-MIZUNO REVERSIBLE WHITE BLUE
# 1820     1420           TTD-221112-SP-V-S23SUC-BH11-BE
# 1821     1422           TTD-221112-SP-V-S23SUC-BH11-BK
# 1822     1426           TTD-221112-SP-V-S23SUC-BH11-DC
# 1823     1428           TTD-221112-SP-V-S23SUC-BH11-LE
# 1824     1430           TTD-221112-SP-V-S23SUC-BH11-LK
# 1825     1432           TTD-221112-SP-V-S23SUC-BH11-YG
# 1826     1451    CIE-221218-Distance Nirvana BK Hat SM
# 1827     1458   CIE-221218-Distance Nirvana BK Hat LXL
# 1828     1604           DYC-US-230210-E11even-705-1005
#
#                                   Mã đơn hàng  \
# 1819  TTD-221216-MIZUNO REVERSIBLE WHITE BLUE
# 1820           TTD-221112-SP-V-S23SUC-BH11-BE
# 1821           TTD-221112-SP-V-S23SUC-BH11-BK
# 1822           TTD-221112-SP-V-S23SUC-BH11-DC
# 1823           TTD-221112-SP-V-S23SUC-BH11-LE
# 1824           TTD-221112-SP-V-S23SUC-BH11-LK
# 1825           TTD-221112-SP-V-S23SUC-BH11-YG
# 1826    CIE-221218-Distance Nirvana BK Hat SM
# 1827   CIE-221218-Distance Nirvana BK Hat LXL
# 1828           DYC-US-230210-E11even-705-1005
#
#                                        Tên ĐH Mã bộ phận Tên bộ phận  \
# 1819  TTD-221216-MIZUNO REVERSIBLE WHITE BLUE       phoi        Phối
# 1820           TTD-221112-SP-V-S23SUC-BH11-BE       phoi        Phối
# 1821           TTD-221112-SP-V-S23SUC-BH11-BK       phoi        Phối
# 1822           TTD-221112-SP-V-S23SUC-BH11-DC       phoi        Phối
# 1823           TTD-221112-SP-V-S23SUC-BH11-LE       phoi        Phối
# 1824           TTD-221112-SP-V-S23SUC-BH11-LK       phoi        Phối
# 1825           TTD-221112-SP-V-S23SUC-BH11-YG       phoi        Phối
# 1826    CIE-221218-Distance Nirvana BK Hat SM       phoi        Phối
# 1827   CIE-221218-Distance Nirvana BK Hat LXL       phoi        Phối
# 1828           DYC-US-230210-E11even-705-1005       phoi        Phối
#
#        Người tạo CV                   Ngày tạo            Ngày Hoàn thành  \
# 1819  Phan Văn Tình  2023-02-07 08:28:45+00:00  2023-02-25 13:06:38+00:00
# 1820  Phan Văn Tình  2023-02-09 10:19:00+00:00  2023-02-23 10:19:44+00:00
# 1821  Phan Văn Tình  2023-02-09 10:22:34+00:00  2023-02-22 09:53:54+00:00
# 1822  Phan Văn Tình  2023-02-09 10:27:03+00:00  2023-02-25 13:12:28+00:00
# 1823  Phan Văn Tình  2023-02-09 10:28:51+00:00  2023-02-22 10:03:31+00:00
# 1824  Phan Văn Tình  2023-02-09 10:30:39+00:00  2023-02-22 09:58:20+00:00
# 1825  Phan Văn Tình  2023-02-09 10:33:27+00:00  2023-02-25 13:15:21+00:00
# 1826  Phan Văn Tình  2023-02-11 09:06:30+00:00  2023-02-23 10:11:12+00:00
# 1827  Phan Văn Tình  2023-02-11 09:21:08+00:00  2023-02-23 10:08:30+00:00
# 1828  Phan Văn Tình  2023-02-16 13:45:09+00:00  2023-03-01 08:25:45+00:00
#
#      Ngày BĐ dự kiến Ngày kết thúc dự kiến  Đồng bộ CV  Tổng số BTP  \
# 1819      2023-03-03            2023-03-04      1622.0       1622.0
# 1820      2023-03-06            2023-03-07      5000.0       5000.0
# 1821      2023-03-07            2023-03-08      6000.0       6000.0
# 1822      2023-03-09            2023-03-10      5000.0       5000.0
# 1823      2023-03-09            2023-03-10      5000.0       5000.0
# 1824      2023-03-10            2023-03-11      4000.0       4000.0
# 1825      2023-03-10            2023-03-11      4000.0       4000.0
# 1826      2023-03-06            2023-03-07       289.0        289.0
# 1827      2023-03-06            2023-03-07       238.0        238.0
# 1828      2023-03-09            2023-03-09       201.0        201.0
#
#      Mã trạng thái Trạng thái CV Nguời xóa CV Nguời hoàn tất CV
# 1819      imported    Đã nhập đủ          NaN               NaN
# 1820      imported    Đã nhập đủ          NaN               NaN
# 1821      imported    Đã nhập đủ          NaN               NaN
# 1822      imported    Đã nhập đủ          NaN               NaN
# 1823      imported    Đã nhập đủ          NaN               NaN
# 1824      imported    Đã nhập đủ          NaN               NaN
# 1825      imported    Đã nhập đủ          NaN               NaN
# 1826      imported    Đã nhập đủ          NaN               NaN
# 1827      imported    Đã nhập đủ          NaN               NaN
# 1828      imported    Đã nhập đủ          NaN               NaN

# %%
dfManufactureTaskDetailFix[dfManufactureTaskDetailFix['task_id'] == 1651]
# Out:
#       task_id                                Tên công việc Mô tả CV  \
# 1793     1651  R2B-140-AC23022749 FAN'S CLUB ALEXIS MONNEY
#
#                                       Mã đơn hàng  \
# 1793  R2B-140-AC23022749 FAN'S CLUB ALEXIS MONNEY
#
#                                            Tên ĐH Mã bộ phận Tên bộ phận  \
# 1793  R2B-140-AC23022749 FAN'S CLUB ALEXIS MONNEY        cat         Cắt
#
#        Người tạo CV                   Ngày tạo            Ngày Hoàn thành  \
# 1793  Phan Văn Tình  2023-02-18 08:55:04+00:00  2023-02-25 08:17:52+00:00
#
#      Ngày BĐ dự kiến Ngày kết thúc dự kiến  Đồng bộ CV  Tổng số BTP  \
# 1793      2023-03-06            2023-03-11        66.0        681.0
#
#      Mã trạng thái Trạng thái CV Nguời xóa CV Nguời hoàn tất CV
# 1793     completed      Hoàn tất          NaN               NaN

# %%
dfManufactureTaskDetailComp = dfManufactureTaskDetailFix[dfManufactureTaskDetailFix['Mã trạng thái'] == 'completed']
dfManufactureTaskDetailApproval = dfManufactureTaskDetailFix[(dfManufactureTaskDetailFix['Mã trạng thái'] == 'approval') | (dfManufactureTaskDetailFix['Mã trạng thái'] == 'review')]
dfManufactureTaskDetailImp = dfManufactureTaskDetailFix[dfManufactureTaskDetailFix['Mã trạng thái'] == 'imported']

# %%
dfManufactureTaskDetailApproval = dfManufactureTaskDetailApproval.rename(columns= {'Ngày Hoàn thành' : 'Ngày sản xuất'})
dfManufactureTaskDetailApproval
# Out:
#      task_id                              Tên công việc Mô tả CV  \
# 0        490  CIE-211222-PBCap - Century Bar - Whitaker
# 1       1136                           HM-221206-WYSSEN
# 2       1178    TTD-221112-MIZUNO RB FAITHFUL CAP WHITE
# 3       1182    TTD-221112-MIZUNO RB FAITHFUL CAP BLACK
# 4       1183    TTD-221112-MIZUNO RB FAITHFUL CAP BLACK
# ..       ...                                        ...      ...
# 391     1710          JP-230131-NAKAJIMA RACING 2023_v1
# 392     1709          JP-230131-NAKAJIMA RACING 2023_v1
# 393     1720                   DYC-US-221222-Takuma-680
# 394     1723           DYC-AU-230222-The Mudgee Brewing
# 395     1724           DYC-AU-230222-The Mudgee Brewing
#
#                                       Mã đơn hàng  \
# 0    CIE-211222-PBCap - Century Bar-Whitaker-60cm
# 1                                HM-221206-WYSSEN
# 2         TTD-221112-MIZUNO RB FAITHFUL CAP WHITE
# 3         TTD-221112-MIZUNO RB FAITHFUL CAP BLACK
# 4         TTD-221112-MIZUNO RB FAITHFUL CAP BLACK
# ..                                            ...
# 391             JP-230131-NAKAJIMA RACING 2023_v1
# 392             JP-230131-NAKAJIMA RACING 2023_v1
# 393                      DYC-US-221222-Takuma-680
# 394              DYC-AU-230222-The Mudgee Brewing
# 395              DYC-AU-230222-The Mudgee Brewing
#
#                                       Tên ĐH Mã bộ phận Tên bộ phận  \
# 0                      CIE-211222-S2023 D1D2   chuan_bi    Chuẩn bị
# 1                           HM-221206-WYSSEN       theu        Thêu
# 2    TTD-221112-MIZUNO RB FAITHFUL CAP WHITE        cat         Cắt
# 3    TTD-221112-MIZUNO RB FAITHFUL CAP BLACK        cat         Cắt
# 4    TTD-221112-MIZUNO RB FAITHFUL CAP BLACK       phoi        Phối
# ..                                       ...        ...         ...
# 391        JP-230131-NAKAJIMA RACING 2023_v1   chuan_bi    Chuẩn bị
# 392        JP-230131-NAKAJIMA RACING 2023_v1       phoi        Phối
# 393                 DYC-US-221222-Takuma-680       phoi        Phối
# 394         DYC-AU-230222-The Mudgee Brewing        cat         Cắt
# 395         DYC-AU-230222-The Mudgee Brewing       phoi        Phối
#
#       Người tạo CV                   Ngày tạo              Ngày sản xuất  \
# 0    Phan Văn Tình  2022-11-16 12:27:01+00:00  2022-11-16 12:27:01+00:00
# 1    Phan Văn Tình  2023-01-16 08:16:59+00:00  2023-01-16 08:17:00+00:00
# 2    Phan Văn Tình  2023-02-03 08:18:09+00:00  2023-02-03 08:18:12+00:00
# 3    Phan Văn Tình  2023-02-03 08:23:36+00:00  2023-02-03 08:23:38+00:00
# 4    Phan Văn Tình  2023-02-03 08:26:29+00:00  2023-02-03 08:26:30+00:00
# ..             ...                        ...                        ...
# 391  Phan Văn Tình  2023-02-23 08:33:18+00:00  2023-02-27 13:09:15+00:00
# 392  Phan Văn Tình  2023-02-23 08:38:31+00:00  2023-03-02 07:55:49+00:00
# 393  Phan Văn Tình  2023-02-24 08:30:17+00:00  2023-02-27 07:35:21+00:00
# 394  Phan Văn Tình  2023-02-24 08:33:12+00:00  2023-02-25 08:15:54+00:00
# 395  Phan Văn Tình  2023-02-24 08:34:54+00:00  2023-02-27 08:01:27+00:00
#
#     Ngày BĐ dự kiến Ngày kết thúc dự kiến  Đồng bộ CV  Tổng số BTP  \
# 0        2022-11-16            2022-11-23         NaN          NaN
# 1        2023-02-14            2023-03-01      1500.0       3000.0
# 2        2023-02-13            2023-02-20      3091.0      28143.0
# 3        2023-02-13            2023-02-20      3091.0      28143.0
# 4        2023-02-22            2023-03-17      5002.0       5002.0
# ..              ...                   ...         ...          ...
# 391      2023-03-06            2023-03-11       146.0        438.0
# 392      2023-03-16            2023-03-17       146.0        146.0
# 393      2023-03-03            2023-03-03       100.0        100.0
# 394      2023-03-01            2023-03-04        67.0        688.0
# 395      2023-03-13            2023-03-14       101.0        101.0
#
#     Mã trạng thái  Trạng thái CV Nguời xóa CV Nguời hoàn tất CV
# 0          review   Chờ sản xuất          NaN               NaN
# 1          review   Chờ sản xuất          NaN               NaN
# 2          review   Chờ sản xuất          NaN               NaN
# 3          review   Chờ sản xuất          NaN               NaN
# 4          review   Chờ sản xuất          NaN               NaN
# ..            ...            ...          ...               ...
# 391      approval  Đang sản xuất          NaN               NaN
# 392      approval  Đang sản xuất          NaN               NaN
# 393      approval  Đang sản xuất          NaN               NaN
# 394      approval  Đang sản xuất          NaN               NaN
# 395      approval  Đang sản xuất          NaN               NaN
#
# [396 rows x 18 columns]

# %%
dfManufactureTaskDetailApproval = dfManufactureTaskDetailApproval.sort_values("Ngày kết thúc dự kiến" , ascending=False).reset_index(drop = True) 
dfManufactureTaskDetailComp = dfManufactureTaskDetailComp.sort_values("Ngày kết thúc dự kiến" , ascending=False).reset_index(drop = True) 
dfManufactureTaskDetailImp = dfManufactureTaskDetailImp.sort_values("Ngày kết thúc dự kiến" , ascending=False).reset_index(drop = True) 
dfManufactureTaskDetailFix = dfManufactureTaskDetailFix.sort_values("Ngày kết thúc dự kiến" , ascending=True).reset_index(drop = True)  
dfManufactureTaskDetailTail = dfManufactureTaskDetailFix.iloc[-500:]
dfManufactureTaskDetailTail
# Out:
#       task_id                      Tên công việc Mô tả CV  \
# 1329     1296  DYC-US-230126-Blacktiph-690-Opt04
# 1330     1293  DYC-US-230126-Blacktiph-690-Opt03
# 1331     1416  CIE-220920-CLB Fondation en Coeur
# 1332     1292  DYC-US-230126-Blacktiph-690-Opt03
# 1333     1425     TTD-221112-SP-V-S23SUC-BH11-DC
# ...       ...                                ...      ...
# 1824     1817              HM-230223-LON LEE 000
# 1825     1814             HM-230223-LON LEE 0002
# 1826     1812             HM-230223-LON LEE 0001
# 1827     1820             HM-230223-LON LEE 0004
# 1828     1811             HM-230223-LON LEE 0001
#
#                             Mã đơn hàng                             Tên ĐH  \
# 1329  DYC-US-230126-Blacktiph-690-Opt04  DYC-US-230126-Blacktiph-690-Opt04
# 1330  DYC-US-230126-Blacktiph-690-Opt03  DYC-US-230126-Blacktiph-690-Opt03
# 1331  CIE-230203-CLB Fondation en Coeur  CIE-230203-CLB Fondation en Coeur
# 1332  DYC-US-230126-Blacktiph-690-Opt03  DYC-US-230126-Blacktiph-690-Opt03
# 1333     TTD-221112-SP-V-S23SUC-BH11-DC     TTD-221112-SP-V-S23SUC-BH11-DC
# ...                                 ...                                ...
# 1824             HM-230223-LON LEE 0003             HM-230223-LON LEE 0003
# 1825             HM-230223-LON LEE 0002             HM-230223-LON LEE 0002
# 1826             HM-230223-LON LEE 0001             HM-230223-LON LEE 0001
# 1827             HM-230223-LON LEE 0004             HM-230223-LON LEE 0004
# 1828             HM-230223-LON LEE 0001             HM-230223-LON LEE 0001
#
#      Mã bộ phận Tên bộ phận   Người tạo CV                   Ngày tạo  \
# 1329   chuan_bi    Chuẩn bị  Phan Văn Tình  2023-02-04 08:39:29+00:00
# 1330       theu        Thêu  Phan Văn Tình  2023-02-04 08:35:57+00:00
# 1331       phoi        Phối  Phan Văn Tình  2023-02-09 10:15:17+00:00
# 1332   chuan_bi    Chuẩn bị  Phan Văn Tình  2023-02-04 08:35:35+00:00
# 1333        cat         Cắt  Phan Văn Tình  2023-02-09 10:26:25+00:00
# ...         ...         ...            ...                        ...
# 1824       phoi        Phối  Phan Văn Tình  2023-02-28 08:46:15+00:00
# 1825       phoi        Phối  Phan Văn Tình  2023-02-28 08:43:03+00:00
# 1826       theu        Thêu  Phan Văn Tình  2023-02-28 08:39:14+00:00
# 1827       phoi        Phối  Phan Văn Tình  2023-02-28 08:53:55+00:00
# 1828       phoi        Phối  Phan Văn Tình  2023-02-28 08:39:56+00:00
#
#                 Ngày Hoàn thành Ngày BĐ dự kiến Ngày kết thúc dự kiến  \
# 1329  2023-02-17 15:17:47+00:00      2023-02-21            2023-02-25
# 1330  2023-02-15 08:15:55+00:00      2023-02-21            2023-02-25
# 1331  2023-03-02 08:10:16+00:00      2023-02-24            2023-02-25
# 1332  2023-02-22 07:47:14+00:00      2023-02-21            2023-02-25
# 1333  2023-02-21 15:10:59+00:00      2023-02-17            2023-02-25
# ...                         ...             ...                   ...
# 1824  2023-02-28 08:46:16+00:00      2023-03-30            2023-03-31
# 1825  2023-02-28 08:43:03+00:00      2023-03-30            2023-03-31
# 1826  2023-02-28 08:39:15+00:00      2023-03-27            2023-03-31
# 1827  2023-02-28 08:53:56+00:00      2023-03-30            2023-03-31
# 1828  2023-02-28 08:39:57+00:00      2023-04-03            2023-04-04
#
#       Đồng bộ CV  Tổng số BTP Mã trạng thái Trạng thái CV Nguời xóa CV  \
# 1329       250.0        250.0     completed      Hoàn tất          NaN
# 1330       250.0        250.0     completed      Hoàn tất          NaN
# 1331       503.0        503.0     completed      Hoàn tất          NaN
# 1332       250.0        250.0     completed      Hoàn tất          NaN
# 1333      3130.0      13130.0     completed      Hoàn tất          NaN
# ...          ...          ...           ...           ...          ...
# 1824       102.0        102.0        review  Chờ sản xuất          NaN
# 1825       104.0        104.0        review  Chờ sản xuất          NaN
# 1826       104.0        312.0        review  Chờ sản xuất          NaN
# 1827       101.0        101.0        review  Chờ sản xuất          NaN
# 1828       104.0        104.0        review  Chờ sản xuất          NaN
#
#      Nguời hoàn tất CV
# 1329               NaN
# 1330               NaN
# 1331               NaN
# 1332               NaN
# 1333               NaN
# ...                ...
# 1824               NaN
# 1825               NaN
# 1826               NaN
# 1827               NaN
# 1828               NaN
#
# [500 rows x 18 columns]

# %%
with pd.ExcelWriter('../dataDA/get_manufacture_task_detail.xlsx') as writer:  
    dfManufactureTaskDetailComp.to_excel(writer, sheet_name='completed')
    dfManufactureTaskDetailApproval.to_excel(writer, sheet_name='approval')
    dfManufactureTaskDetailImp.to_excel(writer, sheet_name='imported')
    dfManufactureTaskDetailFix.to_excel(writer, sheet_name='total')
    dfManufactureTaskDetailTail.to_excel(writer, sheet_name='row_tail')

# %%
dfManufactureTaskDetailFix
# Out:
#       task_id                      Tên công việc  \
# 0          23     Thêu DYC-AU-221020-Kiss My Axe
# 1          14    DYC-US-221004-E11even-647-Opt04
# 2          24          Thêu DYC-AU-221001-Black6
# 3          25  DYC-US-220919-Blacktiph-635-Opt01
# 4          55               BF-220811-FCS KE MOM
# ...       ...                                ...
# 1824     1817              HM-230223-LON LEE 000
# 1825     1814             HM-230223-LON LEE 0002
# 1826     1812             HM-230223-LON LEE 0001
# 1827     1820             HM-230223-LON LEE 0004
# 1828     1811             HM-230223-LON LEE 0001
#
#                                                Mô tả CV  \
# 0
# 1     Rập chóp :MẶT+ĐUÔI : HA-6M-950-58-BF (DAO COTT...
# 2
# 3
# 4
# ...                                                 ...
# 1824
# 1825
# 1826
# 1827
# 1828
#
#                             Mã đơn hàng                             Tên ĐH  \
# 0             DYC-AU-221020-Kiss My Axe          DYC-AU-221020-Kiss My Axe
# 1       DYC-US-221004-E11even-647-Opt04    DYC-US-221004-E11even-647-Opt04
# 2                  DYC-AU-221001-Black6               DYC-AU-221001-Black6
# 3     DYC-US-220919-Blacktiph-635-Opt01  DYC-US-220919-Blacktiph-635-Opt01
# 4                  BF-220811-FCS KE MOM               BF-220811-FCS KE MOM
# ...                                 ...                                ...
# 1824             HM-230223-LON LEE 0003             HM-230223-LON LEE 0003
# 1825             HM-230223-LON LEE 0002             HM-230223-LON LEE 0002
# 1826             HM-230223-LON LEE 0001             HM-230223-LON LEE 0001
# 1827             HM-230223-LON LEE 0004             HM-230223-LON LEE 0004
# 1828             HM-230223-LON LEE 0001             HM-230223-LON LEE 0001
#
#      Mã bộ phận Tên bộ phận     Người tạo CV                   Ngày tạo  \
# 0          theu        Thêu    Phan Văn Tình  2022-11-03 13:46:24+00:00
# 1           cat         Cắt  Trần Minh Thông  2022-11-02 13:23:44+00:00
# 2          theu        Thêu    Phan Văn Tình  2022-11-03 13:49:55+00:00
# 3          theu        Thêu    Phan Văn Tình  2022-11-03 13:54:39+00:00
# 4          theu        Thêu    Phan Văn Tình  2022-11-04 07:47:18+00:00
# ...         ...         ...              ...                        ...
# 1824       phoi        Phối    Phan Văn Tình  2023-02-28 08:46:15+00:00
# 1825       phoi        Phối    Phan Văn Tình  2023-02-28 08:43:03+00:00
# 1826       theu        Thêu    Phan Văn Tình  2023-02-28 08:39:14+00:00
# 1827       phoi        Phối    Phan Văn Tình  2023-02-28 08:53:55+00:00
# 1828       phoi        Phối    Phan Văn Tình  2023-02-28 08:39:56+00:00
#
#                 Ngày Hoàn thành Ngày BĐ dự kiến Ngày kết thúc dự kiến  \
# 0     2022-11-07 12:03:01+00:00      2022-11-03            2022-11-03
# 1     2022-11-07 13:00:31+00:00      2022-11-02            2022-11-03
# 2     2022-11-07 12:03:01+00:00      2022-11-03            2022-11-04
# 3     2022-11-07 12:03:01+00:00      2022-11-03            2022-11-04
# 4     2022-11-07 12:03:01+00:00      2022-11-04            2022-11-04
# ...                         ...             ...                   ...
# 1824  2023-02-28 08:46:16+00:00      2023-03-30            2023-03-31
# 1825  2023-02-28 08:43:03+00:00      2023-03-30            2023-03-31
# 1826  2023-02-28 08:39:15+00:00      2023-03-27            2023-03-31
# 1827  2023-02-28 08:53:56+00:00      2023-03-30            2023-03-31
# 1828  2023-02-28 08:39:57+00:00      2023-04-03            2023-04-04
#
#       Đồng bộ CV  Tổng số BTP Mã trạng thái Trạng thái CV Nguời xóa CV  \
# 0            NaN          NaN     completed      Hoàn tất          NaN
# 1            NaN          NaN     completed      Hoàn tất          NaN
# 2            NaN          NaN     completed      Hoàn tất          NaN
# 3            NaN          NaN     completed      Hoàn tất          NaN
# 4            NaN          NaN     completed      Hoàn tất          NaN
# ...          ...          ...           ...           ...          ...
# 1824       102.0        102.0        review  Chờ sản xuất          NaN
# 1825       104.0        104.0        review  Chờ sản xuất          NaN
# 1826       104.0        312.0        review  Chờ sản xuất          NaN
# 1827       101.0        101.0        review  Chờ sản xuất          NaN
# 1828       104.0        104.0        review  Chờ sản xuất          NaN
#
#      Nguời hoàn tất CV
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 1824               NaN
# 1825               NaN
# 1826               NaN
# 1827               NaN
# 1828               NaN
#
# [1829 rows x 18 columns]
