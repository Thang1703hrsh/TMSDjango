# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = None
pd.options.mode.chained_assignment = None  # default='warn'
from datetime import datetime
now = datetime.now()

# %%
dfProductUnit = pd.read_csv('../data_csv/ProductUnit.csv')
dfProductUnit.reset_index(drop = True)
# Out:
#        product_id  product_unit_id  unit_id  is_default
# 0              21               21        1           1
# 1              21            12018        5           0
# 2              22               22        1           1
# 3              22            12019        5           0
# 4              26               26        1           1
# ...           ...              ...      ...         ...
# 16842       11468            21746        1           1
# 16843       11469            21747        1           1
# 16844       11470            21748        4           1
# 16845       11471            21749        4           1
# 16846       11472            21750        1           1
#
# [16847 rows x 4 columns]

# %%
dfProductUnitExchange = pd.read_csv('../data_csv/ProductUnitExchange.csv')
# dfProductUnitExchange = dfProductUnitExchange.drop_duplicates(subset=['product_id' , 'source_unit_id' , 'result_unit_id'], keep='first').reset_index(drop= True)
dfProductUnitExchange
# Out:
#       product_id  source_unit_id  result_unit_id  source_quantity  \
# 0           6773               4              14         110.0000
# 1           6758               4              14         110.0000
# 2           6773               3              14         115.0000
# 3           2348               1               5           0.9144
# 4            194               1               5           0.9144
# ...          ...             ...             ...              ...
# 6963       11450               1               5           0.9144
# 6964       11449               1               5           0.9144
# 6965       11445               1               5           0.9144
# 6966       11455               1               5           0.9140
# 6967       11454               1               5           0.9140
#
#       result_quantity
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 6963              1.0
# 6964              1.0
# 6965              1.0
# 6966              1.0
# 6967              1.0
#
# [6968 rows x 5 columns]

# %%
dfProductUnitExchange = dfProductUnitExchange.drop_duplicates(subset=['product_id' , 'source_unit_id' , 'result_unit_id'], keep='first').reset_index(drop= True)

# %%
dfPurchaseOrderDetail = pd.read_csv("../data_csv/PurchaseOrderDetail.csv") # Purchase Order
dfStockInPurchaseOrder = pd.read_csv("../data_csv/StockInPurchaseOrder.csv") # Purchase Order
dfPurchaseOrder = pd.read_csv('../data_csv/PurchaseOrder.csv')
dfUsers = pd.read_csv('../data_csv/Users.csv')
dfSupplierDeliveryInfo = pd.read_csv('../data_csv/SupplierDeliveryInfo.csv')
dfSupplierDeliveryInfo
# Out:
#      supplier_id  supplier_delivery_id supplier_code      supplier_name
# 0              1                     1            HG        Hans Global
# 1              2                     2            EV  Everest Shang Hai
# 2              3                     3            EW    Everest Tai Wan
# 3              4                     4            MC          Men Chuen
# 4              5                     5            FT         Flying Tex
# ..           ...                   ...           ...                ...
# 236          236                   243            PT             PERTEX
# 237          237                   244            HB      Shishi HaoBao
# 238          239                   246            YM               YIMA
# 239          240                   247            95              9.5cm
# 240          241                   248            72              7.2cm
#
# [241 rows x 4 columns]

# %%
dfPurchaseOrder = dfPurchaseOrder.merge(dfUsers, on = 'creator_id', how = 'left').replace(np.NaN , 0)
dfPurchaseOrder = dfPurchaseOrder.merge(dfSupplierDeliveryInfo, on = 'supplier_delivery_id', how = 'left').replace(np.NaN , 0)
dfPurchaseOrder
# Out:
#                      code  creator_id              name_po  total_amount  \
# 0     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 1     TTD-02052022-001-MX         344  TTD-02052022-001-MX        1000.0
# 2     TTD-02052022-004-HV         343  TTD-02052022-004-HV        2500.0
# 3     TTD-05052022-005-HN         343  TTD-05052022-005-HN         100.0
# 4     TTD-03052022-006-DI         343  TTD-03052022-006-DI        2000.0
# ...                   ...         ...                  ...           ...
# 1332  TTD-05122022-019-TL         344  TTD-05122022-019-TL       15100.0
# 1333  TTD-05122022-020-HV         343  TTD-05122022-020-HV        1000.0
# 1334  TTD-05122022-021-TQ         344  TTD-05122022-021-TQ           7.0
# 1335  TTD-05122022-022-AN         344  TTD-05122022-022-AN        9100.0
# 1336    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
#
#       purchase_order_id  is_completed  po_status time_create  \
# 0                     1             1  completed  2022-05-04
# 1                     2             1  completed  2022-05-04
# 2                     3             1  completed  2022-05-05
# 3                     4             1  completed  2022-05-05
# 4                     5             1  completed  2022-05-05
# ...                 ...           ...        ...         ...
# 1332               1372             0   approval  2022-12-05
# 1333               1373             0     review  2022-12-05
# 1334               1374             1  completed  2022-12-05
# 1335               1375             0   approval  2022-12-05
# 1336               1376             1  completed  2022-12-27
#
#      estimated_delivery  supplier_delivery_id         fullname  supplier_id  \
# 0                     0                    61  Nguyễn TT Duyên           61
# 1                     0                    74   Nguyễn Thị Anh           74
# 2                     0                   111  Nguyễn TT Duyên          111
# 3                     0                    72  Nguyễn TT Duyên           72
# 4                     0                    65  Nguyễn TT Duyên           65
# ...                 ...                   ...              ...          ...
# 1332         2022-12-19                    67   Nguyễn Thị Anh           67
# 1333         2022-12-31                   111  Nguyễn TT Duyên          111
# 1334         2022-12-06                   116   Nguyễn Thị Anh          116
# 1335         2022-12-19                    99   Nguyễn Thị Anh           99
# 1336                  0                     3  Duong Nguyen s4            3
#
#      supplier_code    supplier_name
# 0               AK          A Khiêm
# 1               MX            Maxim
# 2               HV         Hàn Việt
# 3               HN          Hải Nam
# 4               DI          Dong IL
# ...            ...              ...
# 1332            TL              TTL
# 1333            HV         Hàn Việt
# 1334            TQ            T.Q.A
# 1335            AN         Anh Khôi
# 1336            EW  Everest Tai Wan
#
# [1337 rows x 14 columns]

# %%
df = dfPurchaseOrderDetail[dfPurchaseOrderDetail[['product_id' ,'purchase_order_id']].duplicated() == True]
df = dfStockInPurchaseOrder[~dfStockInPurchaseOrder['purchase_order_id'].isin(dfPurchaseOrderDetail['purchase_order_id'].to_list())].reset_index(drop = True)

# %% [markdown]
# ### Cập nhập lại đơn hàng hoàn tất

# %%
dfPurchaseOrderDetail.at[426, 'is_complete'] = 1
dfPurchaseOrderDetail.at[426, 'is_complete'] = 1
dfPurchaseOrderDetail.at[1785, 'is_complete'] = 1
dfPurchaseOrderDetail.at[1787, 'is_complete'] = 1
dfPurchaseOrderDetail.at[19, 'is_complete'] = 1

# %%
dfPurchaseOrderTotal = dfPurchaseOrder.merge(dfPurchaseOrderDetail, on = 'purchase_order_id', how = 'left').replace(np.NaN , 0)
dfPurchaseOrderTotal[dfPurchaseOrderTotal['product_id'] == 1703]
# Out:
#                      code  creator_id              name_po  total_amount  \
# 2171  TTD-21072022-113-HF         343  TTD-21072022-113-HF        9600.0
# 4577  TTD-28102022-120-HF         343  TTD-28102022-120-HF        8600.0
#
#       purchase_order_id  is_completed po_status time_create  \
# 2171                575             0  approval  2022-07-21
# 4577               1180             0  approval  2022-10-28
#
#      estimated_delivery  supplier_delivery_id         fullname  supplier_id  \
# 2171         2022-12-20                    45  Nguyễn TT Duyên           45
# 4577         2022-11-30                    45  Nguyễn TT Duyên           45
#
#      supplier_code   supplier_name  product_id        product_code  \
# 2171            HF  Hung'S Fortune        1703  1-RPHW1R-INF-00-HF
# 4577            HF  Hung'S Fortune        1703  1-RPHW1R-INF-00-HF
#
#       product_unit_id  purchase_order_quantity  is_complete
# 2171            13558                    200.0            0
# 4577            13558                     50.0            0

# %%
dfPurchaseOrderTotal = dfPurchaseOrder.merge(dfPurchaseOrderDetail, on = 'purchase_order_id', how = 'left').replace(np.NaN , 0)
# dfPurchaseOrderTotalNotComplete = dfPurchaseOrderTotal[(dfPurchaseOrderTotal['is_completed'] != 1) & (dfPurchaseOrderTotal['is_complete'] != 1)
#                                                        & (dfPurchaseOrderTotal['po_status'] == 'approval')]
dfPurchaseOrderDetail = dfPurchaseOrderTotal.merge(dfProductUnit, on = ['product_id' , 'product_unit_id'], how = 'left')
dfPurchaseOrderDetail['quantity_exchange'] = 0
# dfPurchaseOrderDetail[dfPurchaseOrderDetail['product_id'] == 6823]

# %%
dfProductUnitExchange[dfProductUnitExchange['product_id'] == 6823]
# Out:
#       product_id  source_unit_id  result_unit_id  source_quantity  \
# 3774        6823               1               5           0.9144
#
#       result_quantity
# 3774              1.0

# %%
dfPurchaseOrderDetail1 = dfPurchaseOrderDetail.merge(dfProductUnitExchange , left_on = ['product_id','unit_id'] , right_on = ['product_id','result_unit_id'] , how = 'left')
dfPurchaseOrderDetail1['quantity_exchange_not_default'] = dfPurchaseOrderDetail1['purchase_order_quantity'] * dfPurchaseOrderDetail1['source_quantity'] / dfPurchaseOrderDetail1['result_quantity']
dfPurchaseOrderDetail1
# Out:
#                      code  creator_id              name_po  total_amount  \
# 0     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 1     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 2     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 3     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 4     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# ...                   ...         ...                  ...           ...
# 5180  TTD-05122022-022-AN         344  TTD-05122022-022-AN        9100.0
# 5181  TTD-05122022-022-AN         344  TTD-05122022-022-AN        9100.0
# 5182    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
# 5183    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
# 5184    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
#
#       purchase_order_id  is_completed  po_status time_create  \
# 0                     1             1  completed  2022-05-04
# 1                     1             1  completed  2022-05-04
# 2                     1             1  completed  2022-05-04
# 3                     1             1  completed  2022-05-04
# 4                     1             1  completed  2022-05-04
# ...                 ...           ...        ...         ...
# 5180               1375             0   approval  2022-12-05
# 5181               1375             0   approval  2022-12-05
# 5182               1376             1  completed  2022-12-27
# 5183               1376             1  completed  2022-12-27
# 5184               1376             1  completed  2022-12-27
#
#      estimated_delivery  supplier_delivery_id         fullname  supplier_id  \
# 0                     0                    61  Nguyễn TT Duyên           61
# 1                     0                    61  Nguyễn TT Duyên           61
# 2                     0                    61  Nguyễn TT Duyên           61
# 3                     0                    61  Nguyễn TT Duyên           61
# 4                     0                    61  Nguyễn TT Duyên           61
# ...                 ...                   ...              ...          ...
# 5180         2022-12-19                    99   Nguyễn Thị Anh           99
# 5181         2022-12-19                    99   Nguyễn Thị Anh           99
# 5182                  0                     3  Duong Nguyen s4            3
# 5183                  0                     3  Duong Nguyen s4            3
# 5184                  0                     3  Duong Nguyen s4            3
#
#      supplier_code    supplier_name  product_id        product_code  \
# 0               AK          A Khiêm         832  1-KATE00-GSK-00-AK
# 1               AK          A Khiêm        6300  9-CCDCSX-092-00-AK
# 2               AK          A Khiêm        6478  9-CCDCSX-251-00-AK
# 3               AK          A Khiêm        6636  9-FELTCH-SBL-00-AK
# 4               AK          A Khiêm        7793  1-SATIN0-BLK-00-AK
# ...            ...              ...         ...                 ...
# 5180            AN         Anh Khôi        6600  9-GDATMG-WHI-20-AN
# 5181            AN         Anh Khôi       11472  5-DATHUN-WHI-32-AN
# 5182            EW  Everest Tai Wan        6739  9-B07095-SAF-IN-HN
# 5183            EW  Everest Tai Wan        6739  9-B07095-SAF-IN-HN
# 5184            EW  Everest Tai Wan       11470  6-KDHM06-BLK-DA-TQ
#
#       product_unit_id  purchase_order_quantity  is_complete  unit_id  \
# 0                 832                     20.0            0        1
# 1                6300                      1.0            0        4
# 2                6478                     10.0            0        4
# 3                7888                    100.0            0        5
# 4                7793                     70.0            0        1
# ...               ...                      ...          ...      ...
# 5180             6600                   3500.0            0        1
# 5181            21750                    100.0            0        1
# 5182            16162                    200.0            1       14
# 5183            16152                  13010.0            1        4
# 5184            21748                    120.0            1        4
#
#       is_default  quantity_exchange  source_unit_id  result_unit_id  \
# 0              1                  0             NaN             NaN
# 1              1                  0             NaN             NaN
# 2              1                  0             NaN             NaN
# 3              0                  0             1.0             5.0
# 4              1                  0             NaN             NaN
# ...          ...                ...             ...             ...
# 5180           1                  0             NaN             NaN
# 5181           1                  0             NaN             NaN
# 5182           0                  0             4.0            14.0
# 5183           1                  0             NaN             NaN
# 5184           1                  0             NaN             NaN
#
#       source_quantity  result_quantity  quantity_exchange_not_default
# 0                 NaN              NaN                            NaN
# 1                 NaN              NaN                            NaN
# 2                 NaN              NaN                            NaN
# 3              0.9144              1.0                          91.44
# 4                 NaN              NaN                            NaN
# ...               ...              ...                            ...
# 5180              NaN              NaN                            NaN
# 5181              NaN              NaN                            NaN
# 5182          20.0000              1.0                        4000.00
# 5183              NaN              NaN                            NaN
# 5184              NaN              NaN                            NaN
#
# [5185 rows x 27 columns]

# %%
aMate = dfPurchaseOrderDetail1.loc[0].index
for i in range(0 , len(aMate)):
    if(aMate[i] == 'quantity_exchange'):
        a = i
    else: i = i + 1

for i in range(0 , dfPurchaseOrderDetail1.shape[0]):
    aMate = dfPurchaseOrderDetail1.loc[i]
    if(aMate['is_default'] == 1.0):
        dfPurchaseOrderDetail1.iloc[[aMate.name], [a]] = aMate['purchase_order_quantity']
    elif(aMate['is_default'] == 0.0):
        dfPurchaseOrderDetail1.iloc[[aMate.name], [a]] = aMate['quantity_exchange_not_default']

dfPurchaseOrderDetail1[(dfPurchaseOrderDetail1['is_default'] != 0) & (dfPurchaseOrderDetail1['is_default'] != 1)]
dfPurchaseOrderDetail1
# Out:
#                      code  creator_id              name_po  total_amount  \
# 0     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 1     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 2     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 3     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 4     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# ...                   ...         ...                  ...           ...
# 5180  TTD-05122022-022-AN         344  TTD-05122022-022-AN        9100.0
# 5181  TTD-05122022-022-AN         344  TTD-05122022-022-AN        9100.0
# 5182    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
# 5183    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
# 5184    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
#
#       purchase_order_id  is_completed  po_status time_create  \
# 0                     1             1  completed  2022-05-04
# 1                     1             1  completed  2022-05-04
# 2                     1             1  completed  2022-05-04
# 3                     1             1  completed  2022-05-04
# 4                     1             1  completed  2022-05-04
# ...                 ...           ...        ...         ...
# 5180               1375             0   approval  2022-12-05
# 5181               1375             0   approval  2022-12-05
# 5182               1376             1  completed  2022-12-27
# 5183               1376             1  completed  2022-12-27
# 5184               1376             1  completed  2022-12-27
#
#      estimated_delivery  supplier_delivery_id         fullname  supplier_id  \
# 0                     0                    61  Nguyễn TT Duyên           61
# 1                     0                    61  Nguyễn TT Duyên           61
# 2                     0                    61  Nguyễn TT Duyên           61
# 3                     0                    61  Nguyễn TT Duyên           61
# 4                     0                    61  Nguyễn TT Duyên           61
# ...                 ...                   ...              ...          ...
# 5180         2022-12-19                    99   Nguyễn Thị Anh           99
# 5181         2022-12-19                    99   Nguyễn Thị Anh           99
# 5182                  0                     3  Duong Nguyen s4            3
# 5183                  0                     3  Duong Nguyen s4            3
# 5184                  0                     3  Duong Nguyen s4            3
#
#      supplier_code    supplier_name  product_id        product_code  \
# 0               AK          A Khiêm         832  1-KATE00-GSK-00-AK
# 1               AK          A Khiêm        6300  9-CCDCSX-092-00-AK
# 2               AK          A Khiêm        6478  9-CCDCSX-251-00-AK
# 3               AK          A Khiêm        6636  9-FELTCH-SBL-00-AK
# 4               AK          A Khiêm        7793  1-SATIN0-BLK-00-AK
# ...            ...              ...         ...                 ...
# 5180            AN         Anh Khôi        6600  9-GDATMG-WHI-20-AN
# 5181            AN         Anh Khôi       11472  5-DATHUN-WHI-32-AN
# 5182            EW  Everest Tai Wan        6739  9-B07095-SAF-IN-HN
# 5183            EW  Everest Tai Wan        6739  9-B07095-SAF-IN-HN
# 5184            EW  Everest Tai Wan       11470  6-KDHM06-BLK-DA-TQ
#
#       product_unit_id  purchase_order_quantity  is_complete  unit_id  \
# 0                 832                     20.0            0        1
# 1                6300                      1.0            0        4
# 2                6478                     10.0            0        4
# 3                7888                    100.0            0        5
# 4                7793                     70.0            0        1
# ...               ...                      ...          ...      ...
# 5180             6600                   3500.0            0        1
# 5181            21750                    100.0            0        1
# 5182            16162                    200.0            1       14
# 5183            16152                  13010.0            1        4
# 5184            21748                    120.0            1        4
#
#       is_default  quantity_exchange  source_unit_id  result_unit_id  \
# 0              1              20.00             NaN             NaN
# 1              1               1.00             NaN             NaN
# 2              1              10.00             NaN             NaN
# 3              0              91.44             1.0             5.0
# 4              1              70.00             NaN             NaN
# ...          ...                ...             ...             ...
# 5180           1            3500.00             NaN             NaN
# 5181           1             100.00             NaN             NaN
# 5182           0            4000.00             4.0            14.0
# 5183           1           13010.00             NaN             NaN
# 5184           1             120.00             NaN             NaN
#
#       source_quantity  result_quantity  quantity_exchange_not_default
# 0                 NaN              NaN                            NaN
# 1                 NaN              NaN                            NaN
# 2                 NaN              NaN                            NaN
# 3              0.9144              1.0                          91.44
# 4                 NaN              NaN                            NaN
# ...               ...              ...                            ...
# 5180              NaN              NaN                            NaN
# 5181              NaN              NaN                            NaN
# 5182          20.0000              1.0                        4000.00
# 5183              NaN              NaN                            NaN
# 5184              NaN              NaN                            NaN
#
# [5185 rows x 27 columns]

# %%
dfStockInPurchaseOrder
# Out:
#       product_id  purchase_order_id  quantity_arrived actual_delivery_time
# 0           5545                  2             500.0           2022-05-24
# 1            815                  3             639.1           2022-06-01
# 2            811                  3            1079.9           2022-06-23
# 3            815                  3             943.6           2022-06-23
# 4           6773                  4            5000.0           2022-05-24
# ...          ...                ...               ...                  ...
# 5181        6739               1376             200.0           2022-12-27
# 5182        6739               1376             200.0           2022-12-27
# 5183        6739               1376             475.0           2022-12-27
# 5184        6739               1376              20.0           2022-12-27
# 5185        6739               1376            8985.0           2022-12-27
#
# [5186 rows x 4 columns]

# %%
dfPurchaseOrderDetailmerge = dfPurchaseOrderDetail1.merge(dfStockInPurchaseOrder, on = ['purchase_order_id' , 'product_id'], how = 'left').replace(np.NaN , 0)
dfPurchaseOrderDetailmerge['quantity_not_arrived'] = dfPurchaseOrderDetailmerge['quantity_exchange'] - dfPurchaseOrderDetailmerge['quantity_arrived']
dfPurchaseOrderDetailmerge
# Out:
#                      code  creator_id              name_po  total_amount  \
# 0     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 1     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 2     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 3     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 4     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# ...                   ...         ...                  ...           ...
# 5589    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
# 5590    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
# 5591    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
# 5592    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
# 5593    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
#
#       purchase_order_id  is_completed  po_status time_create  \
# 0                     1             1  completed  2022-05-04
# 1                     1             1  completed  2022-05-04
# 2                     1             1  completed  2022-05-04
# 3                     1             1  completed  2022-05-04
# 4                     1             1  completed  2022-05-04
# ...                 ...           ...        ...         ...
# 5589               1376             1  completed  2022-12-27
# 5590               1376             1  completed  2022-12-27
# 5591               1376             1  completed  2022-12-27
# 5592               1376             1  completed  2022-12-27
# 5593               1376             1  completed  2022-12-27
#
#      estimated_delivery  supplier_delivery_id         fullname  supplier_id  \
# 0                     0                    61  Nguyễn TT Duyên           61
# 1                     0                    61  Nguyễn TT Duyên           61
# 2                     0                    61  Nguyễn TT Duyên           61
# 3                     0                    61  Nguyễn TT Duyên           61
# 4                     0                    61  Nguyễn TT Duyên           61
# ...                 ...                   ...              ...          ...
# 5589                  0                     3  Duong Nguyen s4            3
# 5590                  0                     3  Duong Nguyen s4            3
# 5591                  0                     3  Duong Nguyen s4            3
# 5592                  0                     3  Duong Nguyen s4            3
# 5593                  0                     3  Duong Nguyen s4            3
#
#      supplier_code    supplier_name  product_id        product_code  \
# 0               AK          A Khiêm         832  1-KATE00-GSK-00-AK
# 1               AK          A Khiêm        6300  9-CCDCSX-092-00-AK
# 2               AK          A Khiêm        6478  9-CCDCSX-251-00-AK
# 3               AK          A Khiêm        6636  9-FELTCH-SBL-00-AK
# 4               AK          A Khiêm        7793  1-SATIN0-BLK-00-AK
# ...            ...              ...         ...                 ...
# 5589            EW  Everest Tai Wan        6739  9-B07095-SAF-IN-HN
# 5590            EW  Everest Tai Wan        6739  9-B07095-SAF-IN-HN
# 5591            EW  Everest Tai Wan        6739  9-B07095-SAF-IN-HN
# 5592            EW  Everest Tai Wan       11470  6-KDHM06-BLK-DA-TQ
# 5593            EW  Everest Tai Wan       11470  6-KDHM06-BLK-DA-TQ
#
#       product_unit_id  purchase_order_quantity  is_complete  unit_id  \
# 0                 832                     20.0            0        1
# 1                6300                      1.0            0        4
# 2                6478                     10.0            0        4
# 3                7888                    100.0            0        5
# 4                7793                     70.0            0        1
# ...               ...                      ...          ...      ...
# 5589            16152                  13010.0            1        4
# 5590            16152                  13010.0            1        4
# 5591            16152                  13010.0            1        4
# 5592            21748                    120.0            1        4
# 5593            21748                    120.0            1        4
#
#       is_default  quantity_exchange  source_unit_id  result_unit_id  \
# 0              1              20.00             0.0             0.0
# 1              1               1.00             0.0             0.0
# 2              1              10.00             0.0             0.0
# 3              0              91.44             1.0             5.0
# 4              1              70.00             0.0             0.0
# ...          ...                ...             ...             ...
# 5589           1           13010.00             0.0             0.0
# 5590           1           13010.00             0.0             0.0
# 5591           1           13010.00             0.0             0.0
# 5592           1             120.00             0.0             0.0
# 5593           1             120.00             0.0             0.0
#
#       source_quantity  result_quantity  quantity_exchange_not_default  \
# 0              0.0000              0.0                           0.00
# 1              0.0000              0.0                           0.00
# 2              0.0000              0.0                           0.00
# 3              0.9144              1.0                          91.44
# 4              0.0000              0.0                           0.00
# ...               ...              ...                            ...
# 5589           0.0000              0.0                           0.00
# 5590           0.0000              0.0                           0.00
# 5591           0.0000              0.0                           0.00
# 5592           0.0000              0.0                           0.00
# 5593           0.0000              0.0                           0.00
#
#       quantity_arrived actual_delivery_time  quantity_not_arrived
# 0                  0.0                    0                 20.00
# 1                  0.0                    0                  1.00
# 2                  0.0                    0                 10.00
# 3                  0.0                    0                 91.44
# 4                  0.0                    0                 70.00
# ...                ...                  ...                   ...
# 5589             475.0           2022-12-27              12535.00
# 5590              20.0           2022-12-27              12990.00
# 5591            8985.0           2022-12-27               4025.00
# 5592              50.0           2022-12-27                 70.00
# 5593              70.0           2022-12-27                 50.00
#
# [5594 rows x 30 columns]

# %%
dfPurchaseOrderDetailmerge.head(5)
# Out:
#                   code  creator_id              name_po  total_amount  \
# 0  TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 1  TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 2  TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 3  TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 4  TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
#
#    purchase_order_id  is_completed  po_status time_create estimated_delivery  \
# 0                  1             1  completed  2022-05-04                  0
# 1                  1             1  completed  2022-05-04                  0
# 2                  1             1  completed  2022-05-04                  0
# 3                  1             1  completed  2022-05-04                  0
# 4                  1             1  completed  2022-05-04                  0
#
#    supplier_delivery_id         fullname  supplier_id supplier_code  \
# 0                    61  Nguyễn TT Duyên           61            AK
# 1                    61  Nguyễn TT Duyên           61            AK
# 2                    61  Nguyễn TT Duyên           61            AK
# 3                    61  Nguyễn TT Duyên           61            AK
# 4                    61  Nguyễn TT Duyên           61            AK
#
#   supplier_name  product_id        product_code  product_unit_id  \
# 0       A Khiêm         832  1-KATE00-GSK-00-AK              832
# 1       A Khiêm        6300  9-CCDCSX-092-00-AK             6300
# 2       A Khiêm        6478  9-CCDCSX-251-00-AK             6478
# 3       A Khiêm        6636  9-FELTCH-SBL-00-AK             7888
# 4       A Khiêm        7793  1-SATIN0-BLK-00-AK             7793
#
#    purchase_order_quantity  is_complete  unit_id  is_default  \
# 0                     20.0            0        1           1
# 1                      1.0            0        4           1
# 2                     10.0            0        4           1
# 3                    100.0            0        5           0
# 4                     70.0            0        1           1
#
#    quantity_exchange  source_unit_id  result_unit_id  source_quantity  \
# 0              20.00             0.0             0.0           0.0000
# 1               1.00             0.0             0.0           0.0000
# 2              10.00             0.0             0.0           0.0000
# 3              91.44             1.0             5.0           0.9144
# 4              70.00             0.0             0.0           0.0000
#
#    result_quantity  quantity_exchange_not_default  quantity_arrived  \
# 0              0.0                           0.00               0.0
# 1              0.0                           0.00               0.0
# 2              0.0                           0.00               0.0
# 3              1.0                          91.44               0.0
# 4              0.0                           0.00               0.0
#
#   actual_delivery_time  quantity_not_arrived
# 0                    0                 20.00
# 1                    0                  1.00
# 2                    0                 10.00
# 3                    0                 91.44
# 4                    0                 70.00

# %%
dfPurchaseOrderDetailmerge['raw_material_status'] = ''
aMate = dfPurchaseOrderDetailmerge.loc[0].index
for i in range(0 , len(aMate)):
    if(aMate[i] == 'raw_material_status'):
        a = i
    else: i = i + 1

for i in range(0 , len(dfPurchaseOrderDetailmerge)):
    aMate = dfPurchaseOrderDetailmerge.loc[i]
    if(aMate['is_completed'] == 1):
        dfPurchaseOrderDetailmerge.iloc[[aMate.name], [a]] = 'Hoàn tất'
    elif((aMate['is_completed'] == 0) & (aMate['is_complete'] == 0) & (aMate['quantity_arrived'] == 0)):
        dfPurchaseOrderDetailmerge.iloc[[aMate.name], [a]] = 'Chờ nhập kho'
    elif((aMate['is_completed'] == 0) & (aMate['is_complete'] == 0) & (aMate['quantity_arrived'] > 0) & (aMate['quantity_arrived'] < aMate['quantity_exchange'])):
        dfPurchaseOrderDetailmerge.iloc[[aMate.name], [a]] = 'Đã nhập kho 1 phần'
    elif((aMate['is_completed'] == 0) & (aMate['is_complete'] == 0) & (aMate['quantity_arrived'] > 0) & (aMate['quantity_arrived'] > aMate['quantity_exchange'])):
        dfPurchaseOrderDetailmerge.iloc[[aMate.name], [a]] = 'Nhập kho quá số lượng'
    elif((aMate['is_completed'] == 0) & (aMate['is_complete'] == 1)):
        dfPurchaseOrderDetailmerge.iloc[[aMate.name], [a]] = 'Đã nhập đủ'

dfPurchaseOrderDetailmerge
# Out:
#                      code  creator_id              name_po  total_amount  \
# 0     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 1     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 2     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 3     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# 4     TTD-02052022-003-AK         343  TTD-02052022-003-AK         617.0
# ...                   ...         ...                  ...           ...
# 5589    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
# 5590    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
# 5591    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
# 5592    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
# 5593    TTD-27122022-1376         333    TTD-27122022-1376       13330.0
#
#       purchase_order_id  is_completed  po_status time_create  \
# 0                     1             1  completed  2022-05-04
# 1                     1             1  completed  2022-05-04
# 2                     1             1  completed  2022-05-04
# 3                     1             1  completed  2022-05-04
# 4                     1             1  completed  2022-05-04
# ...                 ...           ...        ...         ...
# 5589               1376             1  completed  2022-12-27
# 5590               1376             1  completed  2022-12-27
# 5591               1376             1  completed  2022-12-27
# 5592               1376             1  completed  2022-12-27
# 5593               1376             1  completed  2022-12-27
#
#      estimated_delivery  supplier_delivery_id         fullname  supplier_id  \
# 0                     0                    61  Nguyễn TT Duyên           61
# 1                     0                    61  Nguyễn TT Duyên           61
# 2                     0                    61  Nguyễn TT Duyên           61
# 3                     0                    61  Nguyễn TT Duyên           61
# 4                     0                    61  Nguyễn TT Duyên           61
# ...                 ...                   ...              ...          ...
# 5589                  0                     3  Duong Nguyen s4            3
# 5590                  0                     3  Duong Nguyen s4            3
# 5591                  0                     3  Duong Nguyen s4            3
# 5592                  0                     3  Duong Nguyen s4            3
# 5593                  0                     3  Duong Nguyen s4            3
#
#      supplier_code    supplier_name  product_id        product_code  \
# 0               AK          A Khiêm         832  1-KATE00-GSK-00-AK
# 1               AK          A Khiêm        6300  9-CCDCSX-092-00-AK
# 2               AK          A Khiêm        6478  9-CCDCSX-251-00-AK
# 3               AK          A Khiêm        6636  9-FELTCH-SBL-00-AK
# 4               AK          A Khiêm        7793  1-SATIN0-BLK-00-AK
# ...            ...              ...         ...                 ...
# 5589            EW  Everest Tai Wan        6739  9-B07095-SAF-IN-HN
# 5590            EW  Everest Tai Wan        6739  9-B07095-SAF-IN-HN
# 5591            EW  Everest Tai Wan        6739  9-B07095-SAF-IN-HN
# 5592            EW  Everest Tai Wan       11470  6-KDHM06-BLK-DA-TQ
# 5593            EW  Everest Tai Wan       11470  6-KDHM06-BLK-DA-TQ
#
#       product_unit_id  purchase_order_quantity  is_complete  unit_id  \
# 0                 832                     20.0            0        1
# 1                6300                      1.0            0        4
# 2                6478                     10.0            0        4
# 3                7888                    100.0            0        5
# 4                7793                     70.0            0        1
# ...               ...                      ...          ...      ...
# 5589            16152                  13010.0            1        4
# 5590            16152                  13010.0            1        4
# 5591            16152                  13010.0            1        4
# 5592            21748                    120.0            1        4
# 5593            21748                    120.0            1        4
#
#       is_default  quantity_exchange  source_unit_id  result_unit_id  \
# 0              1              20.00             0.0             0.0
# 1              1               1.00             0.0             0.0
# 2              1              10.00             0.0             0.0
# 3              0              91.44             1.0             5.0
# 4              1              70.00             0.0             0.0
# ...          ...                ...             ...             ...
# 5589           1           13010.00             0.0             0.0
# 5590           1           13010.00             0.0             0.0
# 5591           1           13010.00             0.0             0.0
# 5592           1             120.00             0.0             0.0
# 5593           1             120.00             0.0             0.0
#
#       source_quantity  result_quantity  quantity_exchange_not_default  \
# 0              0.0000              0.0                           0.00
# 1              0.0000              0.0                           0.00
# 2              0.0000              0.0                           0.00
# 3              0.9144              1.0                          91.44
# 4              0.0000              0.0                           0.00
# ...               ...              ...                            ...
# 5589           0.0000              0.0                           0.00
# 5590           0.0000              0.0                           0.00
# 5591           0.0000              0.0                           0.00
# 5592           0.0000              0.0                           0.00
# 5593           0.0000              0.0                           0.00
#
#       quantity_arrived actual_delivery_time  quantity_not_arrived  \
# 0                  0.0                    0                 20.00
# 1                  0.0                    0                  1.00
# 2                  0.0                    0                 10.00
# 3                  0.0                    0                 91.44
# 4                  0.0                    0                 70.00
# ...                ...                  ...                   ...
# 5589             475.0           2022-12-27              12535.00
# 5590              20.0           2022-12-27              12990.00
# 5591            8985.0           2022-12-27               4025.00
# 5592              50.0           2022-12-27                 70.00
# 5593              70.0           2022-12-27                 50.00
#
#      raw_material_status
# 0               Hoàn tất
# 1               Hoàn tất
# 2               Hoàn tất
# 3               Hoàn tất
# 4               Hoàn tất
# ...                  ...
# 5589            Hoàn tất
# 5590            Hoàn tất
# 5591            Hoàn tất
# 5592            Hoàn tất
# 5593            Hoàn tất
#
# [5594 rows x 31 columns]

# %%
dfPurchaseOrderDetailDA = dfPurchaseOrderDetailmerge[['code', 'name_po','total_amount' , 'purchase_order_id' , 'is_completed' , 'is_complete' , 'po_status', 'product_code' , 'supplier_code' , 'supplier_name' , 'purchase_order_quantity' , 'quantity_exchange' , 'quantity_arrived' , 'quantity_not_arrived'
                                                 , 'time_create' , 'estimated_delivery' , 'actual_delivery_time' , 'fullname' , 'raw_material_status']]

dfPurchaseOrderDetailDA.rename(columns = { 'code' : 'Mã ĐH' ,'name_po':'Tên ĐH' ,'total_amount':'Số lượng ĐH đặt' , 'purchase_order_id': 'ID đơn hàng', 'fullname' :'Người tạo ĐH', 'is_completed': 'ĐH hoàn tất ?' , 'is_complete': 'NPL hoàn tất trong ĐH ?' ,
                                         'po_status': 'Trạng thái ĐH' , 'product_code': 'Mã NPL', 'supplier_code' : 'Mã NCC' , 'supplier_name' : 'Tên NCC' , 'purchase_order_quantity' : 'Số lượng NPL đặt' , 'quantity_exchange' : 'Số lượng NPL đặt (đã chuyển đổi)' , 
                                        'quantity_arrived': 'Số lượng nhập kho', 'quantity_not_arrived': 'Số lượng chưa nhập kho' , 'time_create' : 'Thời gian tạo ĐH',
                                        'estimated_delivery' : 'Thời gian giao dự kiến' , 'actual_delivery_time' : 'Thời gian giao thực tế' , 'raw_material_status' : 'Tình trạng NPL'}, inplace = True)
dfPurchaseOrderDetailDA.head(5)
# Out:
#                  Mã ĐH               Tên ĐH  Số lượng ĐH đặt  ID đơn hàng  \
# 0  TTD-02052022-003-AK  TTD-02052022-003-AK            617.0            1
# 1  TTD-02052022-003-AK  TTD-02052022-003-AK            617.0            1
# 2  TTD-02052022-003-AK  TTD-02052022-003-AK            617.0            1
# 3  TTD-02052022-003-AK  TTD-02052022-003-AK            617.0            1
# 4  TTD-02052022-003-AK  TTD-02052022-003-AK            617.0            1
#
#    ĐH hoàn tất ?  NPL hoàn tất trong ĐH ? Trạng thái ĐH              Mã NPL  \
# 0              1                        0     completed  1-KATE00-GSK-00-AK
# 1              1                        0     completed  9-CCDCSX-092-00-AK
# 2              1                        0     completed  9-CCDCSX-251-00-AK
# 3              1                        0     completed  9-FELTCH-SBL-00-AK
# 4              1                        0     completed  1-SATIN0-BLK-00-AK
#
#   Mã NCC  Tên NCC  Số lượng NPL đặt  Số lượng NPL đặt (đã chuyển đổi)  \
# 0     AK  A Khiêm              20.0                             20.00
# 1     AK  A Khiêm               1.0                              1.00
# 2     AK  A Khiêm              10.0                             10.00
# 3     AK  A Khiêm             100.0                             91.44
# 4     AK  A Khiêm              70.0                             70.00
#
#    Số lượng nhập kho  Số lượng chưa nhập kho Thời gian tạo ĐH  \
# 0                0.0                   20.00       2022-05-04
# 1                0.0                    1.00       2022-05-04
# 2                0.0                   10.00       2022-05-04
# 3                0.0                   91.44       2022-05-04
# 4                0.0                   70.00       2022-05-04
#
#   Thời gian giao dự kiến Thời gian giao thực tế     Người tạo ĐH  \
# 0                      0                      0  Nguyễn TT Duyên
# 1                      0                      0  Nguyễn TT Duyên
# 2                      0                      0  Nguyễn TT Duyên
# 3                      0                      0  Nguyễn TT Duyên
# 4                      0                      0  Nguyễn TT Duyên
#
#   Tình trạng NPL
# 0       Hoàn tất
# 1       Hoàn tất
# 2       Hoàn tất
# 3       Hoàn tất
# 4       Hoàn tất

# %%
dfPurchaseOrderDetailDA.to_excel('../dataDA/getPurchaseOrderDetail{}.xlsx'.format(now), index= False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\Admin\Desktop\TMSDjango\temporary\purchase_order.ipynb Cell 20 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/TMSDjango/temporary/purchase_order.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> dfPurchaseOrderDetailDA.to_excel('../dataDA/getPurchaseOrderDetail{}.xlsx'.format(now), index= False)
#
# File c:\Users\Admin\anaconda3\lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353 )
#
# File c:\Users\Admin\anaconda3\lib\site-packages\pandas\io\formats\excel.py:888, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     884     need_save = False
#     885 else:
#     886     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     887     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 888     writer = ExcelWriter(  # type: ignore[abstract]
#     889         writer, engine=engine, storage_options=storage_options
#     890     )
#     891     need_save = True
#     893 try:
#
# File c:\Users\Admin\anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py:191, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     188 if mode == "a":
#     189     raise ValueError("Append mode is not supported with xlsxwriter!")
# --> 191 super().__init__(
#     192     path,
#     193     engine=engine,
#     194     date_format=date_format,
#     195     datetime_format=datetime_format,
#     196     mode=mode,
#     197     storage_options=storage_options,
#     198     if_sheet_exists=if_sheet_exists,
#     199     engine_kwargs=engine_kwargs,
#     200 )
#     202 self.book = Workbook(self.handles.handle, **engine_kwargs)
#
# File c:\Users\Admin\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1106, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1102 self.handles = IOHandles(
#    1103     cast(IO[bytes], path), compression={"compression": None}
#    1104 )
#    1105 if not isinstance(path, ExcelWriter):
# -> 1106     self.handles = get_handle(
#    1107         path, mode, storage_options=storage_options, is_text=False
#    1108     )
#    1109 self.sheets: dict[str, Any] = {}
#    1110 self.cur_sheet = None
#
# File c:\Users\Admin\anaconda3\lib\site-packages\pandas\io\common.py:798, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#    (...)
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
# --> 798         handle = open(handle, ioargs.mode)
#     799     handles.append(handle)
#     801 # Convert BytesIO or file objects passed with an encoding
#
# OSError: [Errno 22] Invalid argument: '../dataDA/getPurchaseOrderDetail2023-03-04 15:51:12.611304.xlsx'

# %%
dfPurchaseOrderDetail.loc[(dfPurchaseOrderDetail['quantity_not_arrived'] < 0), 'quantity_not_arrived'] = 0
dfPurchaseOrderDetailSum = dfPurchaseOrderDetail.groupby(['product_id'], as_index=False)['quantity_not_arrived'].sum()
dfPurchaseOrderDetailSum
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Admin\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Admin\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'quantity_not_arrived'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Admin\Desktop\TMSDjango\temporary\purchase_order.ipynb Cell 21 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/TMSDjango/temporary/purchase_order.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> dfPurchaseOrderDetail.loc[(dfPurchaseOrderDetail['quantity_not_arrived'] < 0), 'quantity_not_arrived'] = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/TMSDjango/temporary/purchase_order.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> dfPurchaseOrderDetailSum = dfPurchaseOrderDetail.groupby(['product_id'], as_index=False)['quantity_not_arrived'].sum()
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/TMSDjango/temporary/purchase_order.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> dfPurchaseOrderDetailSum
#
# File c:\Users\Admin\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\Admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'quantity_not_arrived'

# %%
dfPurchaseOrderDetailSum[dfPurchaseOrderDetailSum['product_id'] == 6823]
# Out:
#      product_id  quantity_not_arrived
# 148        6823                   0.0
